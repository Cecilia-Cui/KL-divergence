# %%
import numpy as np
import pandas as pd
import csv

# 读取 CSV 文件
file_path = "./all_fisher_matrices.csv"  # 更新为实际路径
df = pd.read_csv(file_path)

# 提取数据并构建 Fisher 矩阵
fisher_matrices = {}
for index, row in df.iterrows():
    group = row['Group']
    detector = row['Detector']
    fisher_values = row.iloc[2:].values.astype(float).reshape(9, 9)  # 将数据重塑为9x9矩阵
    key = f"{group}_{detector}"
    fisher_matrices[key] = fisher_values  # 保证矩阵是完整的9维

# %%
# 提取9维矩阵并转换为7维
def extract_relevant_submatrix(matrix, size=7):
    """提取前 size 个参数的子矩阵"""
    return matrix[:size, :size]

# 动态正则化项函数
def get_dynamic_epsilon(matrix):
    cond_number = np.linalg.cond(matrix)
    eigvals = np.linalg.eigvals(matrix)
    eigval_std = np.std(eigvals)
    
    if cond_number > 1e20 or eigval_std > 1e2:
        return 1e-2
    elif cond_number > 1e16 or eigval_std > 1e1:
        return 1e-3
    elif cond_number > 1e12:
        return 1e-4
    else:
        return 1e-6

# 确保矩阵正定
def ensure_positive_definite(matrix, matrix_name=""):
    eigvals, eigvecs = np.linalg.eigh(matrix)
    eigvals_clipped = np.clip(eigvals, 1e-2, 1e3)
    matrix_pos_def = eigvecs @ np.diag(eigvals_clipped) @ eigvecs.T
    return matrix_pos_def

# 正则化矩阵
def regularize_matrix(matrix, matrix_name=""):
    epsilon = get_dynamic_epsilon(matrix)
    matrix_sym = (matrix + matrix.T) / 2
    return ensure_positive_definite(matrix_sym + epsilon * np.eye(matrix.shape[0]), matrix_name)

# 计算协方差矩阵
def compute_covariance(fisher_matrix, matrix_name=""):
    reg_matrix = regularize_matrix(fisher_matrix, matrix_name)
    cov_matrix = np.linalg.pinv(reg_matrix)
    return cov_matrix

# %%
# 动态调节 KL 散度中的 Trace 和均值差项
def dynamic_clip(value, threshold=250):
    return min(value, threshold)

# 计算 KL 散度
def kl_divergence(cov1, mean1, cov2, mean2, matrix_name=""):
    cov2_regularized = regularize_matrix(cov2, matrix_name)
    eigvals_cov2 = np.linalg.eigvals(cov2_regularized)
    if np.any(eigvals_cov2 <= 0):
        print(f"{matrix_name} has non-positive eigenvalues, skipping KL computation.")
        return np.nan

    try:
        inv_cov2 = np.linalg.inv(cov2_regularized)
    except np.linalg.LinAlgError:
        print(f"{matrix_name} inversion failed, skipping KL computation.")
        return np.nan

    term1 = np.trace(inv_cov2 @ cov1)
    term1 = dynamic_clip(term1)
    print(f"{matrix_name} KL term1 (Trace): {term1}")

    sign1, logdet1 = np.linalg.slogdet(cov1)
    sign2, logdet2 = np.linalg.slogdet(cov2_regularized)
    if sign1 <= 0 or sign2 <= 0:
        print(f"{matrix_name} determinant is non-positive.")
        return np.nan

    term2 = logdet2 - logdet1
    print(f"{matrix_name} KL term2 (Log determinant difference): {term2}")

    term3 = (mean2 - mean1).T @ inv_cov2 @ (mean2 - mean1)
    term3 = dynamic_clip(term3)
    print(f"{matrix_name} KL term3 (Mean difference): {term3}")

    result = 0.5 * (term1 + term2 + term3 - cov1.shape[0])
    print(f"{matrix_name} KL result: {result}")

    return max(result, 0)

# 计算每个 Fisher 矩阵的协方差矩阵和均值
cov_matrices = {}
means = {}
for key, fisher_matrix in fisher_matrices.items():
    matrix_7d = extract_relevant_submatrix(fisher_matrix)  # 提取前7个参数的子矩阵
    cov_matrix = compute_covariance(matrix_7d, key)
    mean_vector = np.mean(cov_matrix, axis=0)
    cov_matrices[key] = cov_matrix
    means[key] = mean_vector

# %%
# 按组计算 KL 散度并保存结果
results = []
groups = df['Group'].unique()

for group in groups:
    group_detectors = [key for key in cov_matrices.keys() if key.startswith(group)]
    if len(group_detectors) >= 3:  # 假设每组有三个探测器
        kl_12 = kl_divergence(cov_matrices[f'{group}_ET_1'], means[f'{group}_ET_1'], 
                              cov_matrices[f'{group}_ET_2'], means[f'{group}_ET_2'], "matrix_12")
        kl_13 = kl_divergence(cov_matrices[f'{group}_ET_1'], means[f'{group}_ET_1'], 
                              cov_matrices[f'{group}_ET_3'], means[f'{group}_ET_3'], "matrix_13")
        kl_23 = kl_divergence(cov_matrices[f'{group}_ET_2'], means[f'{group}_ET_2'], 
                              cov_matrices[f'{group}_ET_3'], means[f'{group}_ET_3'], "matrix_23")

        results.append({
            'group': group,
            'kl_12': kl_12,
            'kl_13': kl_13,
            'kl_23': kl_23,
        })

# 保存结果到CSV文件
output_file = "kl_divergence_results_regularized.csv"
with open(output_file, mode='w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=['group', 'kl_12', 'kl_13', 'kl_23'])
    writer.writeheader()
    writer.writerows(results)

print(f"KL divergence results saved to {output_file}")
# Out:
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.081915413911243
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.54095770695562
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 12.464402714826157
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 252.7322013574131
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 12.582754223128681
# matrix_23 KL term3 (Mean difference): 32.01983171406041
# matrix_23 KL result: 143.80129296859454
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 6.683407226802238
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.8417036134011
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 7.197776724948259
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.09888836247413
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.009241200119874
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.50462060005992
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.468774686884677
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.23438734344234
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 6.8346815440369415
# matrix_13 KL term3 (Mean difference): 95.965226733479
# matrix_13 KL result: 172.89995413875795
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.599594899126183
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.7997974495631
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.978997658754757
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.48949882937737
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 7.953110285958797
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.4765551429794
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 6.923124138636894
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.96156206931846
# matrix_12 KL term1 (Trace): 191.45251717516436
# matrix_12 KL term2 (Log determinant difference): 9.751328414080314
# matrix_12 KL term3 (Mean difference): 46.90925482132811
# matrix_12 KL result: 120.5565502052864
# matrix_13 KL term1 (Trace): 199.08988958662047
# matrix_13 KL term2 (Log determinant difference): 9.794486686073757
# matrix_13 KL term3 (Mean difference): 52.681067595391816
# matrix_13 KL result: 127.28272193404302
# matrix_23 KL term1 (Trace): 229.41303557522355
# matrix_23 KL term2 (Log determinant difference): 9.257945270176588
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 240.83549042270005
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.0804175756080046
# matrix_12 KL term3 (Mean difference): 183.49367988662908
# matrix_12 KL result: 216.78704873111855
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 7.7643747831877725
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.38218739159387
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.041183036313143
# matrix_23 KL term3 (Mean difference): 224.9169015343276
# matrix_23 KL result: 238.47904228532036
# matrix_12 KL term1 (Trace): 240.4767023660071
# matrix_12 KL term2 (Log determinant difference): 7.791973950922387
# matrix_12 KL term3 (Mean difference): 13.855156011237549
# matrix_12 KL result: 127.56191616408353
# matrix_13 KL term1 (Trace): 236.5177506325667
# matrix_13 KL term2 (Log determinant difference): 9.625490855054696
# matrix_13 KL term3 (Mean difference): 18.24032744460422
# matrix_13 KL result: 128.6917844661128
# matrix_23 KL term1 (Trace): 145.85737589631324
# matrix_23 KL term2 (Log determinant difference): 11.107308267920068
# matrix_23 KL term3 (Mean difference): 32.468544930658496
# matrix_23 KL result: 91.21661454744591
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.708465836649145
# matrix_12 KL term3 (Mean difference): 167.26559216442251
# matrix_12 KL result: 209.98702900053584
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 6.925974673232703
# matrix_13 KL term3 (Mean difference): 110.27548968243123
# matrix_13 KL result: 180.10073217783196
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 5.1860416483982466
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.09302082419913
# matrix_12 KL term1 (Trace): 184.4666409785798
# matrix_12 KL term2 (Log determinant difference): 9.848817162744202
# matrix_12 KL term3 (Mean difference): 66.79333679395181
# matrix_12 KL result: 127.0543974676379
# matrix_13 KL term1 (Trace): 161.53194388031744
# matrix_13 KL term2 (Log determinant difference): 10.56839377800965
# matrix_13 KL term3 (Mean difference): 57.609596499026644
# matrix_13 KL result: 111.35496707867686
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.931049674356203
# matrix_23 KL term3 (Mean difference): 46.101667898132966
# matrix_23 KL result: 149.51635878624458
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.954791783953416
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 251.4773958919767
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.29573359690768
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.64786679845383
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 6.648133942508085
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.82406697125404
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.879930316173851
# matrix_12 KL term3 (Mean difference): 145.29691663077958
# matrix_12 KL result: 198.58842347347672
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 10.4083654485469
# matrix_13 KL term3 (Mean difference): 207.51453533232615
# matrix_13 KL result: 230.4614503904365
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 10.739828669092796
# matrix_23 KL term3 (Mean difference): 5.750940860178133
# matrix_23 KL result: 129.74538476463545
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.942599791435331
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.97129989571766
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 10.03826587669952
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 251.51913293834977
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 10.306352954049611
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 251.6531764770248
# matrix_12 KL term1 (Trace): 235.91183968170844
# matrix_12 KL term2 (Log determinant difference): 9.554886303109637
# matrix_12 KL term3 (Mean difference): 23.398430274094267
# matrix_12 KL result: 130.93257812945618
# matrix_13 KL term1 (Trace): 175.68751455935669
# matrix_13 KL term2 (Log determinant difference): 9.279253319420455
# matrix_13 KL term3 (Mean difference): 17.762051891798734
# matrix_13 KL result: 97.86440988528794
# matrix_23 KL term1 (Trace): 217.71081085665745
# matrix_23 KL term2 (Log determinant difference): 8.948854328856012
# matrix_23 KL term3 (Mean difference): 13.158101099031011
# matrix_23 KL result: 116.40888314227223
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 6.284188708481267
# matrix_12 KL term3 (Mean difference): 2.3099107749442993
# matrix_12 KL result: 125.79704974171278
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 6.675092971517612
# matrix_13 KL term3 (Mean difference): 3.2632787520429636
# matrix_13 KL result: 126.46918586178026
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.00139297772383
# matrix_23 KL term3 (Mean difference): 91.40926818119041
# matrix_23 KL result: 171.7053305794571
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.749593652684956
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.87479682634248
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.387251327653061
# matrix_13 KL term3 (Mean difference): 185.27162024980197
# matrix_13 KL result: 218.82943578872752
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.849774555866695
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 251.42488727793335
# matrix_12 KL term1 (Trace): 42.78873394172342
# matrix_12 KL term2 (Log determinant difference): 8.814371725354139
# matrix_12 KL term3 (Mean difference): 113.73414264779254
# matrix_12 KL result: 79.16862415743505
# matrix_13 KL term1 (Trace): 84.3898421141084
# matrix_13 KL term2 (Log determinant difference): 10.30464612683077
# matrix_13 KL term3 (Mean difference): 239.79458492375232
# matrix_13 KL result: 163.74453658234575
# matrix_23 KL term1 (Trace): 59.05920566781121
# matrix_23 KL term2 (Log determinant difference): 10.703214119857629
# matrix_23 KL term3 (Mean difference): 21.93980144046577
# matrix_23 KL result: 42.35111061406731
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.36939082172173
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.68469541086085
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.318646572001253
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 251.1593232860006
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.713286265574826
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.8566431327874
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 5.358188358798046
# matrix_12 KL term3 (Mean difference): 204.4824343445497
# matrix_12 KL result: 226.42031135167386
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 5.653608136242729
# matrix_13 KL term3 (Mean difference): 190.00358690645882
# matrix_13 KL result: 219.3285975213508
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.527717070748116
# matrix_23 KL term3 (Mean difference): 23.427067851927035
# matrix_23 KL result: 137.97739246133756
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 10.16735620034338
# matrix_12 KL term3 (Mean difference): 127.64203225555248
# matrix_12 KL result: 190.4046942279479
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.573114427772062
# matrix_13 KL term3 (Mean difference): 168.1779146451566
# matrix_13 KL result: 210.37551453646432
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.617460112820627
# matrix_23 KL term3 (Mean difference): 240.26149884404066
# matrix_23 KL result: 245.93947947843066
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 10.401646566276696
# matrix_12 KL term3 (Mean difference): 6.200677267513868
# matrix_12 KL result: 129.80116191689527
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 12.921795138697542
# matrix_13 KL term3 (Mean difference): 6.918001957403848
# matrix_13 KL result: 131.4198985480507
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 11.790690084442959
# matrix_23 KL term3 (Mean difference): 223.04197943627355
# matrix_23 KL result: 238.91633476035827
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.144475359103541
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 251.07223767955176
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 11.402390564147542
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 252.20119528207377
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 11.487878972268444
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 252.24393948613422
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.465733891216834
# matrix_12 KL term3 (Mean difference): 91.44841648034327
# matrix_12 KL result: 171.95707518578004
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 6.994956646598887
# matrix_13 KL term3 (Mean difference): 61.54631115582517
# matrix_13 KL result: 155.77063390121202
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 4.447640503653563
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 248.7238202518268
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.115491505134313
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 251.05774575256714
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.530986028632608
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 251.2654930143163
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.627321725556211
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 251.3136608627781
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 10.84947757422886
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 251.92473878711442
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 7.924491745061179
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.4622458725306
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 5.956714491455909
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.47835724572795
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 6.825147338402235
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.91257366920112
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.777393358648386
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.8886966793242
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 10.665223280969652
# matrix_23 KL term3 (Mean difference): 81.07600130863213
# matrix_23 KL result: 167.37061229480088
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 4.147663486203594
# matrix_12 KL term3 (Mean difference): 222.1678862287265
# matrix_12 KL result: 234.65777485746503
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 4.4481622409595065
# matrix_13 KL term3 (Mean difference): 193.7864446051812
# matrix_13 KL result: 220.61730342307035
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.569669153068363
# matrix_23 KL term3 (Mean difference): 10.651268780689149
# matrix_23 KL result: 131.61046896687876
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 4.263890552920243
# matrix_12 KL term3 (Mean difference): 30.820542150268835
# matrix_12 KL result: 139.04221635159453
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 4.488280191761373
# matrix_13 KL term3 (Mean difference): 25.180557056582842
# matrix_13 KL result: 136.3344186241721
# matrix_23 KL term1 (Trace): 123.60352227915175
# matrix_23 KL term2 (Log determinant difference): 7.726710341146546
# matrix_23 KL term3 (Mean difference): 21.68221142328356
# matrix_23 KL result: 73.00622202179093
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.964831531853216
# matrix_12 KL term3 (Mean difference): 207.58859438580333
# matrix_12 KL result: 229.77671295882828
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.391756188307307
# matrix_13 KL term3 (Mean difference): 153.35229190982773
# matrix_13 KL result: 202.8720240490675
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.638143208858407
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 251.3190716044292
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 14.161650632997617
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 253.58082531649882
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 7.785187074148116
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.39259353707405
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 0.5926527536851349
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 246.79632637684256
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.419249754984097
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 251.20962487749205
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.413325886653974
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.706662943327
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 7.9732869712489585
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.48664348562448
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.611193672431058
# matrix_12 KL term3 (Mean difference): 8.71856164618688
# matrix_12 KL result: 130.66487765930896
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.123010830348141
# matrix_13 KL term3 (Mean difference): 13.387836070569815
# matrix_13 KL result: 132.75542345045898
# matrix_23 KL term1 (Trace): 242.01843195084047
# matrix_23 KL term2 (Log determinant difference): 8.732923047309951
# matrix_23 KL term3 (Mean difference): 1.742086357550221
# matrix_23 KL result: 122.74672067785032
# matrix_12 KL term1 (Trace): 196.12164971137616
# matrix_12 KL term2 (Log determinant difference): 10.041144572678618
# matrix_12 KL term3 (Mean difference): 185.60883778537513
# matrix_12 KL result: 192.38581603471494
# matrix_13 KL term1 (Trace): 138.28792070400854
# matrix_13 KL term2 (Log determinant difference): 9.177165425711808
# matrix_13 KL term3 (Mean difference): 128.5802259136283
# matrix_13 KL result: 134.52265602167432
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.376112022548375
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.6880560112742
# matrix_12 KL term1 (Trace): 68.63212303777789
# matrix_12 KL term2 (Log determinant difference): 9.309992109507505
# matrix_12 KL term3 (Mean difference): 23.359527858811845
# matrix_12 KL result: 47.15082150304862
# matrix_13 KL term1 (Trace): 24.81109263220185
# matrix_13 KL term2 (Log determinant difference): 9.16249586132831
# matrix_13 KL term3 (Mean difference): 7.711135334607766
# matrix_13 KL result: 17.342361914068963
# matrix_23 KL term1 (Trace): 54.50594487119042
# matrix_23 KL term2 (Log determinant difference): 9.063737565951104
# matrix_23 KL term3 (Mean difference): 12.269199404608791
# matrix_23 KL result: 34.41944092087516
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.242656294962746
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 251.12132814748136
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 12.546949723647565
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 252.7734748618238
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 12.576904141538161
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 252.78845207076904
# matrix_12 KL term1 (Trace): 49.55174635354822
# matrix_12 KL term2 (Log determinant difference): 10.824901154356677
# matrix_12 KL term3 (Mean difference): 3.443869841079888
# matrix_12 KL result: 28.41025867449239
# matrix_13 KL term1 (Trace): 55.83550435066647
# matrix_13 KL term2 (Log determinant difference): 10.94697694791905
# matrix_13 KL term3 (Mean difference): 3.735569375356098
# matrix_13 KL result: 31.759025336970808
# matrix_23 KL term1 (Trace): 166.29324657386445
# matrix_23 KL term2 (Log determinant difference): 9.336320097624254
# matrix_23 KL term3 (Mean difference): 68.09889524424248
# matrix_23 KL result: 118.3642309578656
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 4.098607694182526
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 248.54930384709127
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 3.4070469475916045
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 248.2035234737958
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 6.270306217988653
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.63515310899433
# matrix_12 KL term1 (Trace): 90.53019178697424
# matrix_12 KL term2 (Log determinant difference): 9.243074127378739
# matrix_12 KL term3 (Mean difference): 44.65128992946579
# matrix_12 KL result: 68.71227792190939
# matrix_13 KL term1 (Trace): 87.96413927915518
# matrix_13 KL term2 (Log determinant difference): 10.125759326186316
# matrix_13 KL term3 (Mean difference): 38.64918962999397
# matrix_13 KL result: 64.86954411766773
# matrix_23 KL term1 (Trace): 197.8583385334584
# matrix_23 KL term2 (Log determinant difference): 10.09662464185045
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 225.47748158765444
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 11.187409905542525
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 252.09370495277128
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.927172385694611
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 251.46358619284732
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 7.543827176717954
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.27191358835898
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.35781359525548
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.67890679762775
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.864547857539538
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.93227392876977
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.717958708189865
# matrix_23 KL term3 (Mean difference): 155.7173755787394
# matrix_23 KL result: 204.21766714346464
# matrix_12 KL term1 (Trace): 142.40375750550385
# matrix_12 KL term2 (Log determinant difference): 9.134892816775107
# matrix_12 KL term3 (Mean difference): 41.92502995708157
# matrix_12 KL result: 93.23184013968026
# matrix_13 KL term1 (Trace): 89.68010573227382
# matrix_13 KL term2 (Log determinant difference): 12.854224114152778
# matrix_13 KL term3 (Mean difference): 26.679041588443127
# matrix_13 KL result: 61.10668571743486
# matrix_23 KL term1 (Trace): 74.80428057510082
# matrix_23 KL term2 (Log determinant difference): 12.362300767538159
# matrix_23 KL term3 (Mean difference): 2.68838182794122
# matrix_23 KL result: 41.427481585290096
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.797054078015883
# matrix_12 KL term3 (Mean difference): 69.74784016862395
# matrix_12 KL result: 160.77244712331992
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.690136759874335
# matrix_13 KL term3 (Mean difference): 72.42310552740035
# matrix_13 KL result: 162.55662114363736
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 10.147339322102976
# matrix_23 KL term3 (Mean difference): 23.37848084798411
# matrix_23 KL result: 138.26291008504356
# matrix_12 KL term1 (Trace): 97.58481398640268
# matrix_12 KL term2 (Log determinant difference): 9.03180693446674
# matrix_12 KL term3 (Mean difference): 10.983020580703057
# matrix_12 KL result: 55.29982075078624
# matrix_13 KL term1 (Trace): 213.36765692397591
# matrix_13 KL term2 (Log determinant difference): 9.478574399980902
# matrix_13 KL term3 (Mean difference): 23.196090493884142
# matrix_13 KL result: 119.52116090892048
# matrix_23 KL term1 (Trace): 198.49908573923562
# matrix_23 KL term2 (Log determinant difference): 9.661623370199246
# matrix_23 KL term3 (Mean difference): 137.7884040637398
# matrix_23 KL result: 169.4745565865873
# matrix_12 KL term1 (Trace): 98.07776930880064
# matrix_12 KL term2 (Log determinant difference): 12.08718845333185
# matrix_12 KL term3 (Mean difference): 18.217072538726768
# matrix_12 KL result: 60.69101515042962
# matrix_13 KL term1 (Trace): 39.900192195483115
# matrix_13 KL term2 (Log determinant difference): 9.09536114717072
# matrix_13 KL term3 (Mean difference): 6.378915711219835
# matrix_13 KL result: 24.187234526936834
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 6.220661152994744
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.61033057649738
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.417272366841303
# matrix_12 KL term3 (Mean difference): 75.33610745074336
# matrix_12 KL result: 163.87668990879234
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.22868285382625
# matrix_13 KL term3 (Mean difference): 74.78573192751608
# matrix_13 KL result: 163.50720739067117
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.024339053828324
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 251.01216952691416
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.75549673520398
# matrix_12 KL term3 (Mean difference): 227.95714123089067
# matrix_12 KL result: 239.85631898304732
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 10.486857856466498
# matrix_13 KL term3 (Mean difference): 247.98470682503776
# matrix_13 KL result: 250.7357823407521
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 10.948179305490838
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 251.97408965274542
# matrix_12 KL term1 (Trace): 20.095968035172255
# matrix_12 KL term2 (Log determinant difference): 10.441426985474367
# matrix_12 KL term3 (Mean difference): 15.362806482188558
# matrix_12 KL result: 19.45010075141759
# matrix_13 KL term1 (Trace): 7.69655278595132
# matrix_13 KL term2 (Log determinant difference): 9.135308741907702
# matrix_13 KL term3 (Mean difference): 3.865338928544391
# matrix_13 KL result: 6.8486002282017076
# matrix_23 KL term1 (Trace): 61.956723367814305
# matrix_23 KL term2 (Log determinant difference): 7.913984695650308
# matrix_23 KL term3 (Mean difference): 41.932866631337106
# matrix_23 KL result: 52.40178734740086
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.334688829161763
# matrix_12 KL term3 (Mean difference): 97.52469792248297
# matrix_12 KL result: 174.42969337582238
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.338701501405199
# matrix_13 KL term3 (Mean difference): 99.16395839311707
# matrix_13 KL result: 175.25132994726113
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.022091342712999
# matrix_23 KL term3 (Mean difference): 31.237973273272416
# matrix_23 KL result: 141.6300323079927
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.32229787616008
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.66114893808003
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 10.214259946510197
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 251.6071299732551
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.929848193505482
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 251.46492409675275
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.820301683069072
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.91015084153454
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.70894430922031
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.85447215461016
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.12138023873867
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 251.06069011936933
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.43919692475771
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 251.21959846237885
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.445733025273485
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.72286651263676
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.21701385768173
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.60850692884085
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.551479112853722
# matrix_12 KL term3 (Mean difference): 148.35314940096717
# matrix_12 KL result: 200.45231425691043
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 13.548598870893393
# matrix_13 KL term3 (Mean difference): 243.45344753478568
# matrix_13 KL result: 250.00102320283952
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 13.221088802379317
# matrix_23 KL term3 (Mean difference): 138.21702798400366
# matrix_23 KL result: 197.2190583931915
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.103307526716712
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 251.05165376335836
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.822191395386884
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.91109569769344
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.610834567498191
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.8054172837491
# matrix_12 KL term1 (Trace): 33.74592204598582
# matrix_12 KL term2 (Log determinant difference): 8.757083529823571
# matrix_12 KL term3 (Mean difference): 16.682989858464605
# matrix_12 KL result: 26.092997717137003
# matrix_13 KL term1 (Trace): 23.7968877633365
# matrix_13 KL term2 (Log determinant difference): 8.587875302072227
# matrix_13 KL term3 (Mean difference): 8.742755415767746
# matrix_13 KL result: 17.063759240588237
# matrix_23 KL term1 (Trace): 37.49051984962614
# matrix_23 KL term2 (Log determinant difference): 9.06244831294632
# matrix_23 KL term3 (Mean difference): 14.505186331102447
# matrix_23 KL result: 27.029077246837453
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.051943259905299
# matrix_12 KL term3 (Mean difference): 2.698833791970803
# matrix_12 KL result: 126.87538852593804
# matrix_13 KL term1 (Trace): 193.9770533451947
# matrix_13 KL term2 (Log determinant difference): 7.013773160800895
# matrix_13 KL term3 (Mean difference): 3.0322997966267877
# matrix_13 KL result: 98.51156315131118
# matrix_23 KL term1 (Trace): 79.1842394391133
# matrix_23 KL term2 (Log determinant difference): 8.2015396810914
# matrix_23 KL term3 (Mean difference): 6.8177881339844735
# matrix_23 KL result: 43.60178362709459
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.678837032461107
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.33941851623055
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 7.800124886949316
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.40006244347467
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.796411595532213
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.8982057977661
# matrix_12 KL term1 (Trace): 100.0351210111295
# matrix_12 KL term2 (Log determinant difference): 10.041227238263486
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 176.5381741246965
# matrix_13 KL term1 (Trace): 146.69715514060715
# matrix_13 KL term2 (Log determinant difference): 9.575034708955803
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 199.63609492478147
# matrix_23 KL term1 (Trace): 167.41429544083178
# matrix_23 KL term2 (Log determinant difference): 8.75850593167083
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 209.5864006862513
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 6.874131418505339
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.93706570925266
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 7.434836699832843
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.21741834991641
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 7.507207683461409
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.2536038417307
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.516335039163753
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.7581675195819
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.033552021397893
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.51677601069895
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.72959258799686
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.86479629399844
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 10.023558044169395
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 251.5117790220847
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 11.05039698226147
# matrix_13 KL term3 (Mean difference): 153.37680352386303
# matrix_13 KL result: 203.71360025306225
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 7.98154333262808
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.49077166631403
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.433841087034228
# matrix_12 KL term3 (Mean difference): 176.72028333713627
# matrix_12 KL result: 214.07706221208525
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 7.0466780613328055
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.0233390306664
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 6.938473248503783
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.9692366242519
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 10.094994758313401
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 251.5474973791567
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 5.275968345433142
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 249.13798417271659
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 3.5498687658407597
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 248.27493438292038
# matrix_12 KL term1 (Trace): 115.01566753896913
# matrix_12 KL term2 (Log determinant difference): 8.956909295021797
# matrix_12 KL term3 (Mean difference): 0.9344338914640176
# matrix_12 KL result: 58.95350536272747
# matrix_13 KL term1 (Trace): 32.44363909540483
# matrix_13 KL term2 (Log determinant difference): 8.335442364762976
# matrix_13 KL term3 (Mean difference): 0.12810679259972058
# matrix_13 KL result: 16.953594126383766
# matrix_23 KL term1 (Trace): 160.66170343383317
# matrix_23 KL term2 (Log determinant difference): 8.608338022804737
# matrix_23 KL term3 (Mean difference): 96.76611019685515
# matrix_23 KL result: 129.51807582674653
# matrix_12 KL term1 (Trace): 53.17301008682561
# matrix_12 KL term2 (Log determinant difference): 9.986994275176478
# matrix_12 KL term3 (Mean difference): 10.903160459126676
# matrix_12 KL result: 33.53158241056438
# matrix_13 KL term1 (Trace): 60.600548265585736
# matrix_13 KL term2 (Log determinant difference): 10.950414036256841
# matrix_13 KL term3 (Mean difference): 7.539256458750182
# matrix_13 KL result: 36.04510938029638
# matrix_23 KL term1 (Trace): 47.56500821310442
# matrix_23 KL term2 (Log determinant difference): 10.721483398754796
# matrix_23 KL term3 (Mean difference): 8.96303458987116
# matrix_23 KL result: 30.124763100865188
# matrix_12 KL term1 (Trace): 46.54561773865824
# matrix_12 KL term2 (Log determinant difference): 9.207134501925953
# matrix_12 KL term3 (Mean difference): 18.62816068082621
# matrix_12 KL result: 33.6904564607052
# matrix_13 KL term1 (Trace): 101.81498032643196
# matrix_13 KL term2 (Log determinant difference): 9.264125994312096
# matrix_13 KL term3 (Mean difference): 42.46118515268156
# matrix_13 KL result: 73.2701457367128
# matrix_23 KL term1 (Trace): 65.49665675532574
# matrix_23 KL term2 (Log determinant difference): 9.268800250425475
# matrix_23 KL term3 (Mean difference): 15.514202438489844
# matrix_23 KL result: 41.63982972212053
# matrix_12 KL term1 (Trace): 14.567369484615611
# matrix_12 KL term2 (Log determinant difference): 9.121300859150443
# matrix_12 KL term3 (Mean difference): 39.757260688381855
# matrix_12 KL result: 28.222965516073955
# matrix_13 KL term1 (Trace): 9.955585852254295
# matrix_13 KL term2 (Log determinant difference): 8.763141242529382
# matrix_13 KL term3 (Mean difference): 21.864215403668172
# matrix_13 KL result: 16.791471249225925
# matrix_23 KL term1 (Trace): 13.041179774636795
# matrix_23 KL term2 (Log determinant difference): 8.85724601178492
# matrix_23 KL term3 (Mean difference): 37.85803967685385
# matrix_23 KL result: 26.37823273163778
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.26689282663903
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 251.13344641331952
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.466941147769687
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.73347057388483
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.445154110152226
# matrix_23 KL term3 (Mean difference): 86.06411615922251
# matrix_23 KL result: 168.75463513468736
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.485486969194275
# matrix_12 KL term3 (Mean difference): 212.64042412000882
# matrix_12 KL result: 232.56295554460155
# matrix_13 KL term1 (Trace): 172.352225380856
# matrix_13 KL term2 (Log determinant difference): 9.228640945874302
# matrix_13 KL term3 (Mean difference): 116.76613741078468
# matrix_13 KL result: 145.67350186875748
# matrix_23 KL term1 (Trace): 144.41998152270997
# matrix_23 KL term2 (Log determinant difference): 8.958353782847047
# matrix_23 KL term3 (Mean difference): 35.49563374560759
# matrix_23 KL result: 90.9369845255823
# matrix_12 KL term1 (Trace): 33.92434912606774
# matrix_12 KL term2 (Log determinant difference): 9.281931765153066
# matrix_12 KL term3 (Mean difference): 110.81447429358936
# matrix_12 KL result: 73.51037759240508
# matrix_13 KL term1 (Trace): 22.95382226598926
# matrix_13 KL term2 (Log determinant difference): 8.757846679698337
# matrix_13 KL term3 (Mean difference): 64.12057463185167
# matrix_13 KL result: 44.41612178876963
# matrix_23 KL term1 (Trace): 33.69308737760409
# matrix_23 KL term2 (Log determinant difference): 8.735012774190812
# matrix_23 KL term3 (Mean difference): 111.5699653568697
# matrix_23 KL result: 73.4990327543323
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.260870722698133
# matrix_12 KL term3 (Mean difference): 91.22786166327141
# matrix_12 KL result: 170.74436619298478
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 6.912701878199648
# matrix_13 KL term3 (Mean difference): 102.57199712708822
# matrix_13 KL result: 176.24234950264395
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.885803956295245
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.94290197814763
# matrix_12 KL term1 (Trace): 30.219351432455582
# matrix_12 KL term2 (Log determinant difference): 9.869307119767354
# matrix_12 KL term3 (Mean difference): 0.4055017248431934
# matrix_12 KL result: 16.747080138533065
# matrix_13 KL term1 (Trace): 42.85707228156879
# matrix_13 KL term2 (Log determinant difference): 9.042124625579369
# matrix_13 KL term3 (Mean difference): 0.3235910862333129
# matrix_13 KL result: 22.611393996690737
# matrix_23 KL term1 (Trace): 54.46532940205789
# matrix_23 KL term2 (Log determinant difference): 8.38855025732843
# matrix_23 KL term3 (Mean difference): 4.4298685446307395
# matrix_23 KL result: 30.14187410200853
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 10.840824891033451
# matrix_12 KL term3 (Mean difference): 12.492300202665495
# matrix_12 KL result: 133.16656254684946
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 12.631571550465095
# matrix_13 KL term3 (Mean difference): 12.276333599090751
# matrix_13 KL result: 133.95395257477793
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 11.036069635280006
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 252.01803481764
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.912824555949111
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.45641227797455
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 7.290827192077543
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.14541359603876
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 6.330886436315332
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.66544321815766
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.048797401574083
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.52439870078703
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.996261258082981
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.9981306290415
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 10.161891853740197
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 251.5809459268701
# matrix_12 KL term1 (Trace): 77.86295760526956
# matrix_12 KL term2 (Log determinant difference): 9.70328222555904
# matrix_12 KL term3 (Mean difference): 59.98046835501335
# matrix_12 KL result: 70.27335409292097
# matrix_13 KL term1 (Trace): 56.851640969747336
# matrix_13 KL term2 (Log determinant difference): 9.481931235702792
# matrix_13 KL term3 (Mean difference): 75.94393440872
# matrix_13 KL result: 67.63875330708507
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.99170994397431
# matrix_23 KL term3 (Mean difference): 10.98666542558696
# matrix_23 KL result: 131.48918768478063
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.713400432254694
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.35670021612734
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.518503543455783
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.7592517717279
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 7.745601754391874
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.37280087719594
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 10.156345779458274
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 251.57817288972913
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 10.974188396347241
# matrix_13 KL term3 (Mean difference): 202.19485574526783
# matrix_13 KL result: 228.08452207080754
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 10.516569087327063
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 251.75828454366354
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.175216318330527
# matrix_12 KL term3 (Mean difference): 162.83230758815787
# matrix_12 KL result: 207.50376195324418
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 12.641398921950415
# matrix_13 KL term3 (Mean difference): 214.12766163056696
# matrix_13 KL result: 234.88453027625872
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 12.694197561565407
# matrix_23 KL term3 (Mean difference): 7.2604944966478095
# matrix_23 KL result: 131.47734602910663
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 10.369840822888094
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 251.68492041144404
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.173492141586038
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.58674607079303
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 7.018773408091356
# matrix_23 KL term3 (Mean difference): 186.26959381155692
# matrix_23 KL result: 218.14418360982415
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 13.1125618759808
# matrix_12 KL term3 (Mean difference): 120.14762758524529
# matrix_12 KL result: 188.13009473061305
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 7.331367329044433
# matrix_13 KL term3 (Mean difference): 75.157598079599
# matrix_13 KL result: 162.7444827043217
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 1.155472853371089
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 247.07773642668553
# matrix_12 KL term1 (Trace): 47.36613610473495
# matrix_12 KL term2 (Log determinant difference): 7.381354447788365
# matrix_12 KL term3 (Mean difference): 0.20553869645582745
# matrix_12 KL result: 23.97651462448957
# matrix_13 KL term1 (Trace): 103.50955661362454
# matrix_13 KL term2 (Log determinant difference): 9.983086052480463
# matrix_13 KL term3 (Mean difference): 0.5577490134635141
# matrix_13 KL result: 53.52519583978426
# matrix_23 KL term1 (Trace): 17.611268826393328
# matrix_23 KL term2 (Log determinant difference): 11.812117630689766
# matrix_23 KL term3 (Mean difference): 2.40717121902218
# matrix_23 KL result: 12.415278838052636
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.553327760503896
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 251.27666388025196
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 10.925038432609002
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 251.9625192163045
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.31149981302743
# matrix_23 KL term3 (Mean difference): 188.94226039590254
# matrix_23 KL result: 220.626880104465
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.2487112268021
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 251.12435561340106
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.63496228502691
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.81748114251346
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.611904225401931
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.80595211270096
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.904792269083517
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 251.45239613454177
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 10.456037293743412
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 251.7280186468717
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.908025232132191
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.9540126160661
# matrix_12 KL term1 (Trace): 129.68874557895276
# ...
# matrix_13 KL result: 140.18372178960342
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 14.96943865738746
# matrix_23 KL term3 (Mean difference): 10.624296658109872
# matrix_23 KL result: 134.29686765774866
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.135151412611725
# matrix_12 KL term3 (Mean difference): 136.52798826353995
# matrix_12 KL result: 193.33156983807584
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.111275908275399
# matrix_13 KL term3 (Mean difference): 65.69906867268776
# matrix_13 KL result: 158.40517229048157
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.007180532568846
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.50359026628442
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.004897333762147
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 251.00244866688107
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.188664591853128
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 251.09433229592656
# matrix_23 KL term1 (Trace): 198.80573394543478
# matrix_23 KL term2 (Log determinant difference): 9.394464450884934
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 225.60009919815985
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.663063890214106
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.33153194510706
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.725202629384723
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.86260131469237
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.556065200134137
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 251.27803260006706
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.75837780011423
# matrix_12 KL term3 (Mean difference): 81.85227444223794
# matrix_12 KL result: 167.30532612117608
# matrix_13 KL term1 (Trace): 207.51762819527394
# matrix_13 KL term2 (Log determinant difference): 8.983513769283308
# matrix_13 KL term3 (Mean difference): 49.6547629204385
# matrix_13 KL result: 129.5779524424979
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 6.198188782947456
# matrix_23 KL term3 (Mean difference): 85.64672868930334
# matrix_23 KL result: 167.4224587361254
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 3.974349605949895
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 248.48717480297495
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 3.782677015044378
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 248.3913385075222
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 7.8142524186848235
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.4071262093424
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.27758396762732
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.13879198381366
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 5.343487716454668
# matrix_13 KL term3 (Mean difference): 246.33075006120364
# matrix_13 KL result: 247.33711888882914
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 5.129883693866677
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.06494184693332
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.510569317197383
# matrix_12 KL term3 (Mean difference): 209.58852008433584
# matrix_12 KL result: 230.5495447007666
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 10.743623732606332
# matrix_13 KL term3 (Mean difference): 217.0610861167865
# matrix_13 KL result: 235.40235492469643
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 11.448977215590913
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 252.22448860779545
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.141346765451733
# matrix_12 KL term3 (Mean difference): 217.88347063334797
# matrix_12 KL result: 234.01240869939983
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.683809487670857
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 251.3419047438354
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 11.78971310585716
# matrix_23 KL term3 (Mean difference): 91.1660724451965
# matrix_23 KL result: 172.97789277552684
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 5.277929264921061
# matrix_12 KL term3 (Mean difference): 48.70752501815823
# matrix_12 KL result: 148.49272714153963
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 4.476221019769806
# matrix_13 KL term3 (Mean difference): 50.03726687645464
# matrix_13 KL result: 148.75674394811222
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.38079217892238
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.6903960894612
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 4.30686028438183
# matrix_12 KL term3 (Mean difference): 213.25978612179787
# matrix_12 KL result: 230.28332320308985
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 4.9558051604530995
# matrix_13 KL term3 (Mean difference): 190.08482502132284
# matrix_13 KL result: 219.02031509088798
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.862074447460706
# matrix_23 KL term3 (Mean difference): 25.42580823627295
# matrix_23 KL result: 139.14394134186682
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.365053310420786
# matrix_12 KL term3 (Mean difference): 7.960781847107372
# matrix_12 KL result: 130.16291757876408
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 10.89725590775256
# matrix_13 KL term3 (Mean difference): 10.42450716525895
# matrix_13 KL result: 132.16088153650574
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 10.821315472330506
# matrix_23 KL term3 (Mean difference): 47.208649915487754
# matrix_23 KL result: 150.51498269390913
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 6.5291951470352
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.7645975735176
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 6.258038675389887
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 249.62901933769496
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.408938542012766
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.7044692710064
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.434665035432891
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.21733251771644
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 7.002730370189255
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.00136518509464
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 7.48538624800722
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.2426931240036
# matrix_12 KL term1 (Trace): 10.94639138240833
# matrix_12 KL term2 (Log determinant difference): 8.636954618786
# matrix_12 KL term3 (Mean difference): 12.67724360777261
# matrix_12 KL result: 12.63029480448347
# matrix_13 KL term1 (Trace): 9.96595342213844
# matrix_13 KL term2 (Log determinant difference): 8.469648356593439
# matrix_13 KL term3 (Mean difference): 8.882473228967982
# matrix_13 KL result: 10.15903750384993
# matrix_23 KL term1 (Trace): 18.394114715311844
# matrix_23 KL term2 (Log determinant difference): 9.099127400017593
# matrix_23 KL term3 (Mean difference): 41.011469044108075
# matrix_23 KL result: 30.752355579718753
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 6.631264866715851
# matrix_12 KL term3 (Mean difference): 16.249357680878532
# matrix_12 KL result: 132.9403112737972
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 6.016892952764163
# matrix_13 KL term3 (Mean difference): 18.133257337688434
# matrix_13 KL result: 133.57507514522632
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.099601453393301
# matrix_23 KL term3 (Mean difference): 220.9065236586299
# matrix_23 KL result: 236.0030625560116
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.746089582973228
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.87304479148662
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 7.492212152580041
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.24610607629003
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 7.744097056330492
# matrix_23 KL term3 (Mean difference): 77.32424216385792
# matrix_23 KL result: 164.03416961009418
# matrix_12 KL term1 (Trace): 77.59562492436905
# matrix_12 KL term2 (Log determinant difference): 8.430987596232995
# matrix_12 KL term3 (Mean difference): 171.26420568995277
# matrix_12 KL result: 125.1454091052774
# matrix_13 KL term1 (Trace): 61.186391093982195
# matrix_13 KL term2 (Log determinant difference): 8.832587341309543
# matrix_13 KL term3 (Mean difference): 130.84411957386737
# matrix_13 KL result: 96.93154900457955
# matrix_23 KL term1 (Trace): 94.66201874360291
# matrix_23 KL term2 (Log determinant difference): 9.644131520813252
# matrix_23 KL term3 (Mean difference): 179.05909211920485
# matrix_23 KL result: 138.1826211918105
# matrix_12 KL term1 (Trace): 16.88040898600275
# matrix_12 KL term2 (Log determinant difference): 9.177376946520152
# matrix_12 KL term3 (Mean difference): 1.2872101904319286
# matrix_12 KL result: 10.172498061477414
# matrix_13 KL term1 (Trace): 59.49946648386222
# matrix_13 KL term2 (Log determinant difference): 11.046123879622657
# matrix_13 KL term3 (Mean difference): 5.171338297976455
# matrix_13 KL result: 34.35846433073067
# matrix_23 KL term1 (Trace): 63.66967921123491
# matrix_23 KL term2 (Log determinant difference): 11.079962783449941
# matrix_23 KL term3 (Mean difference): 15.533573931536584
# matrix_23 KL result: 41.641607963110715
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.790916849103123
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.89545842455155
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.454382366596366
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 251.22719118329817
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.27350553822075
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 251.1367527691104
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 6.2254079120585
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.61270395602924
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 7.208378086526521
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.10418904326326
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.045355200970514
# matrix_23 KL term3 (Mean difference): 113.79916978388482
# matrix_23 KL result: 182.92226249242765
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 11.667825088680932
# matrix_12 KL term3 (Mean difference): 7.974762645353813
# matrix_12 KL result: 131.32129386701737
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.938211701265438
# matrix_13 KL term3 (Mean difference): 1.0720853525229432
# matrix_13 KL result: 127.0051485268942
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 5.211266375224355
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.10563318761217
# matrix_12 KL term1 (Trace): 4.99753490151485
# matrix_12 KL term2 (Log determinant difference): 9.095822269740186
# matrix_12 KL term3 (Mean difference): 4.012534791404516
# matrix_12 KL result: 5.552945981329776
# matrix_13 KL term1 (Trace): 5.027791077954991
# matrix_13 KL term2 (Log determinant difference): 9.335841758570915
# matrix_13 KL term3 (Mean difference): 5.65958398178776
# matrix_13 KL result: 6.511608409156832
# matrix_23 KL term1 (Trace): 6.173245387682464
# matrix_23 KL term2 (Log determinant difference): 9.478783567379473
# matrix_23 KL term3 (Mean difference): 9.963435142607162
# matrix_23 KL result: 9.307732048834549
# matrix_12 KL term1 (Trace): 141.31069605911046
# matrix_12 KL term2 (Log determinant difference): 7.932122400213052
# matrix_12 KL term3 (Mean difference): 18.954922017108146
# matrix_12 KL result: 80.59887023821582
# matrix_13 KL term1 (Trace): 197.8961621148739
# matrix_13 KL term2 (Log determinant difference): 9.430229574635549
# matrix_13 KL term3 (Mean difference): 26.894859203029785
# matrix_13 KL result: 113.61062544626962
# matrix_23 KL term1 (Trace): 85.51862362924675
# matrix_23 KL term2 (Log determinant difference): 10.732223980430609
# matrix_23 KL term3 (Mean difference): 3.54284346057411
# matrix_23 KL result: 46.39684553512573
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.329479169767849
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 251.16473958488393
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.562466942662969
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 251.2812334713315
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.444140537895311
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 251.22207026894765
# matrix_12 KL term1 (Trace): 70.1238871708063
# matrix_12 KL term2 (Log determinant difference): 9.269560663790351
# matrix_12 KL term3 (Mean difference): 202.41932124106518
# matrix_12 KL result: 137.40638453783092
# matrix_13 KL term1 (Trace): 56.725085236303514
# matrix_13 KL term2 (Log determinant difference): 8.351839364131642
# matrix_13 KL term3 (Mean difference): 159.5708550030811
# matrix_13 KL result: 108.82388980175813
# matrix_23 KL term1 (Trace): 55.63932978646302
# matrix_23 KL term2 (Log determinant difference): 8.299729346654118
# matrix_23 KL term3 (Mean difference): 179.98160231614466
# matrix_23 KL result: 118.4603307246309
# matrix_12 KL term1 (Trace): 127.212975238246
# matrix_12 KL term2 (Log determinant difference): 8.070993310176878
# matrix_12 KL term3 (Mean difference): 73.55381304860344
# matrix_12 KL result: 100.91889079851316
# matrix_13 KL term1 (Trace): 137.32480766114762
# matrix_13 KL term2 (Log determinant difference): 10.279734726473464
# matrix_13 KL term3 (Mean difference): 76.70028009659272
# matrix_13 KL result: 108.6524112421069
# matrix_23 KL term1 (Trace): 59.80099126456284
# matrix_23 KL term2 (Log determinant difference): 11.430759887327564
# matrix_23 KL term3 (Mean difference): 8.498024263742463
# matrix_23 KL result: 36.364887707816436
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.151503672682319
# matrix_12 KL term3 (Mean difference): 16.457725528219115
# matrix_12 KL result: 134.30461460045072
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.50089268458233
# matrix_13 KL term3 (Mean difference): 19.782659348902886
# matrix_13 KL result: 136.1417760167426
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.467102413189474
# matrix_23 KL term3 (Mean difference): 204.84471230754178
# matrix_23 KL result: 228.65590736036563
# KL divergence results saved to kl_divergence_results_regularized.csv
