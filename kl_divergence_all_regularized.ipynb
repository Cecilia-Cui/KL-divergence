# %%
import numpy as np
import pandas as pd
import csv

# 读取 CSV 文件
file_path = "./all_fisher_matrices.csv"  # 更新为实际路径
df = pd.read_csv(file_path)

# 提取数据并构建 Fisher 矩阵
fisher_matrices = {}
for index, row in df.iterrows():
    group = row['Group']
    detector = row['Detector']
    fisher_values = row.iloc[2:].values.astype(float).reshape(9, 9)  # 将数据重塑为9x9矩阵
    key = f"{group}_{detector}"
    fisher_matrices[key] = fisher_values  # 保证矩阵是完整的9维

# %%
# 动态正则化项函数
def get_dynamic_epsilon(matrix):
    cond_number = np.linalg.cond(matrix)
    eigvals = np.linalg.eigvals(matrix)
    eigval_std = np.std(eigvals)
    
    if cond_number > 1e20 or eigval_std > 1e2:
        return 1e-2
    elif cond_number > 1e16 or eigval_std > 1e1:
        return 1e-3
    elif cond_number > 1e12:
        return 1e-4
    else:
        return 1e-6

# 确保矩阵正定
def ensure_positive_definite(matrix, matrix_name=""):
    eigvals, eigvecs = np.linalg.eigh(matrix)
    eigvals_clipped = np.clip(eigvals, 1e-2, 1e3)
    matrix_pos_def = eigvecs @ np.diag(eigvals_clipped) @ eigvecs.T
    return matrix_pos_def

# 正则化矩阵
def regularize_matrix(matrix, matrix_name=""):
    epsilon = get_dynamic_epsilon(matrix)
    matrix_sym = (matrix + matrix.T) / 2
    return ensure_positive_definite(matrix_sym + epsilon * np.eye(matrix.shape[0]), matrix_name)

# 计算协方差矩阵
def compute_covariance(fisher_matrix, matrix_name=""):
    reg_matrix = regularize_matrix(fisher_matrix, matrix_name)
    cov_matrix = np.linalg.pinv(reg_matrix)
    return cov_matrix

# %%
# 动态调节 KL 散度中的 Trace 和均值差项
def dynamic_clip(value, threshold=250):
    return min(value, threshold)

# 计算 KL 散度
def kl_divergence(cov1, mean1, cov2, mean2, matrix_name=""):
    cov2_regularized = regularize_matrix(cov2, matrix_name)
    eigvals_cov2 = np.linalg.eigvals(cov2_regularized)
    if np.any(eigvals_cov2 <= 0):
        print(f"{matrix_name} has non-positive eigenvalues, skipping KL computation.")
        return np.nan

    try:
        inv_cov2 = np.linalg.inv(cov2_regularized)
    except np.linalg.LinAlgError:
        print(f"{matrix_name} inversion failed, skipping KL computation.")
        return np.nan

    term1 = np.trace(inv_cov2 @ cov1)
    term1 = dynamic_clip(term1)
    print(f"{matrix_name} KL term1 (Trace): {term1}")

    sign1, logdet1 = np.linalg.slogdet(cov1)
    sign2, logdet2 = np.linalg.slogdet(cov2_regularized)
    if sign1 <= 0 or sign2 <= 0:
        print(f"{matrix_name} determinant is non-positive.")
        return np.nan

    term2 = logdet2 - logdet1
    print(f"{matrix_name} KL term2 (Log determinant difference): {term2}")

    term3 = (mean2 - mean1).T @ inv_cov2 @ (mean2 - mean1)
    term3 = dynamic_clip(term3)
    print(f"{matrix_name} KL term3 (Mean difference): {term3}")

    result = 0.5 * (term1 + term2 + term3 - cov1.shape[0])
    print(f"{matrix_name} KL result: {result}")

    return max(result, 0)

# 计算每个 Fisher 矩阵的协方差矩阵和均值
cov_matrices = {}
means = {}
for key, fisher_matrix in fisher_matrices.items():
    cov_matrix = compute_covariance(fisher_matrix, key)
    mean_vector = np.mean(cov_matrix, axis=0)
    cov_matrices[key] = cov_matrix
    means[key] = mean_vector

# %%
# 按组计算 KL 散度并保存结果
results = []
groups = df['Group'].unique()

for group in groups:
    group_detectors = [key for key in cov_matrices.keys() if key.startswith(group)]
    if len(group_detectors) >= 3:  # 假设每组有三个探测器
        kl_12 = kl_divergence(cov_matrices[f'{group}_ET_1'], means[f'{group}_ET_1'], 
                              cov_matrices[f'{group}_ET_2'], means[f'{group}_ET_2'], "matrix_12")
        kl_13 = kl_divergence(cov_matrices[f'{group}_ET_1'], means[f'{group}_ET_1'], 
                              cov_matrices[f'{group}_ET_3'], means[f'{group}_ET_3'], "matrix_13")
        kl_23 = kl_divergence(cov_matrices[f'{group}_ET_2'], means[f'{group}_ET_2'], 
                              cov_matrices[f'{group}_ET_3'], means[f'{group}_ET_3'], "matrix_23")

        results.append({
            'group': group,
            'kl_12': kl_12,
            'kl_13': kl_13,
            'kl_23': kl_23,
        })

# 保存结果到CSV文件
output_file = "kl_divergence_results_regularized.csv"
with open(output_file, mode='w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=['group', 'kl_12', 'kl_13', 'kl_23'])
    writer.writeheader()
    writer.writerows(results)

print(f"KL divergence results saved to {output_file}")
# Out:
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.465740883044745
# matrix_12 KL term3 (Mean difference): 243.26570135582074
# matrix_12 KL result: 246.86572111943275
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 12.680606507766564
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 251.8403032538833
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 12.453706943455272
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 251.72685347172762
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.802855386437269
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.40142769321864
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.32302834523227
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 249.66151417261614
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.740236421370884
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.37011821068543
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.637295453832163
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.31864772691608
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 7.168689737428554
# matrix_13 KL term3 (Mean difference): 212.39367778135073
# matrix_13 KL result: 230.28118375938965
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.164416718486176
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.08220835924308
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.962232117660863
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.48111605883042
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.808595917644753
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 249.90429795882238
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 10.063190155183685
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.53159507759185
# matrix_12 KL term1 (Trace): 160.46345659387643
# matrix_12 KL term2 (Log determinant difference): 9.792321062810288
# matrix_12 KL term3 (Mean difference): 10.559800404038388
# matrix_12 KL result: 85.90778903036255
# matrix_13 KL term1 (Trace): 182.74620374112484
# matrix_13 KL term2 (Log determinant difference): 9.977208843469345
# matrix_13 KL term3 (Mean difference): 17.47170324815672
# matrix_13 KL result: 100.59755791637546
# matrix_23 KL term1 (Trace): 197.44744530506878
# matrix_23 KL term2 (Log determinant difference): 9.456329497921615
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 223.95188740149518
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.083257239628733
# matrix_12 KL term3 (Mean difference): 160.00392990140853
# matrix_12 KL result: 204.54359357051862
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 7.981008249723619
# matrix_13 KL term3 (Mean difference): 103.86968800062604
# matrix_13 KL result: 176.42534812517482
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.122161193829495
# matrix_23 KL term3 (Mean difference): 180.27315986239515
# matrix_23 KL result: 215.1976605281123
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.3900726735906375
# matrix_12 KL term3 (Mean difference): 2.564344804896184
# matrix_12 KL result: 125.4772087392434
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.215897138377667
# matrix_13 KL term3 (Mean difference): 5.035341763754704
# matrix_13 KL result: 127.6256194510662
# matrix_23 KL term1 (Trace): 130.37812899355407
# matrix_23 KL term2 (Log determinant difference): 11.180062391559495
# matrix_23 KL term3 (Mean difference): 19.322525123247924
# matrix_23 KL result: 75.94035825418074
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 11.010878731966777
# matrix_12 KL term3 (Mean difference): 164.49411826602235
# matrix_12 KL result: 208.25249849899456
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 7.901838677768012
# matrix_13 KL term3 (Mean difference): 109.77358073686891
# matrix_13 KL result: 179.33770970731845
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 6.107178785777233
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 248.55358939288863
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 10.104753604773855
# matrix_12 KL term3 (Mean difference): 88.43832892730232
# matrix_12 KL result: 169.7715412660381
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 10.37466871301482
# matrix_13 KL term3 (Mean difference): 186.38777562073662
# matrix_13 KL result: 218.88122216687572
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.565144354702312
# matrix_23 KL term3 (Mean difference): 29.297084301826416
# matrix_23 KL result: 139.93111432826436
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 10.76950613704409
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.88475306852206
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.516717633368662
# matrix_13 KL term3 (Mean difference): 206.23526174201513
# matrix_13 KL result: 227.8759896876919
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 6.970660055067983
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 248.985330027534
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.7522206704147
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.87611033520736
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.764183469803484
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.38209173490173
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 10.288413265701323
# matrix_23 KL term3 (Mean difference): 55.412158296306956
# matrix_23 KL result: 153.35028578100412
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.979423782113155
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.98971189105657
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.461486381225832
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.2307431906129
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.734746426714288
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.36737321335715
# matrix_12 KL term1 (Trace): 222.05245080957235
# matrix_12 KL term2 (Log determinant difference): 9.485572635312892
# matrix_12 KL term3 (Mean difference): 36.80985121936863
# matrix_12 KL result: 129.67393733212694
# matrix_13 KL term1 (Trace): 163.62910723000402
# matrix_13 KL term2 (Log determinant difference): 9.234393233400228
# matrix_13 KL term3 (Mean difference): 34.02244696085574
# matrix_13 KL result: 98.94297371213
# matrix_23 KL term1 (Trace): 156.74417083090367
# matrix_23 KL term2 (Log determinant difference): 9.030597006963534
# matrix_23 KL term3 (Mean difference): 21.827728440957753
# matrix_23 KL result: 89.30124813941248
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.717500632037568
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.35875031601879
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 7.515821132272404
# matrix_13 KL term3 (Mean difference): 226.9373288840643
# matrix_13 KL result: 237.72657500816834
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.025121432513124
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.01256071625656
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.97222992154483
# matrix_12 KL term3 (Mean difference): 107.1627785354641
# matrix_12 KL result: 178.56750422850448
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.25018871458585
# matrix_13 KL term3 (Mean difference): 194.95486582430314
# matrix_13 KL result: 222.60252726944452
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.539142815311724
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.26957140765586
# matrix_12 KL term1 (Trace): 84.69903796128739
# matrix_12 KL term2 (Log determinant difference): 9.464822774680973
# matrix_12 KL term3 (Mean difference): 201.36806167104203
# matrix_12 KL result: 143.26596120350519
# matrix_13 KL term1 (Trace): 120.37223238128651
# matrix_13 KL term2 (Log determinant difference): 10.088359628761541
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 185.73029600502403
# matrix_23 KL term1 (Trace): 107.80342875080873
# matrix_23 KL term2 (Log determinant difference): 10.148580860502427
# matrix_23 KL term3 (Mean difference): 19.041607858296214
# matrix_23 KL result: 63.99680873480368
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.915944607203674
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.45797230360185
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 10.536234729427632
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.76811736471382
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.838360004961855
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.4191800024809
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 5.637986278572519
# matrix_12 KL term3 (Mean difference): 18.66199930211837
# matrix_12 KL result: 132.64999279034544
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 5.803379868123681
# matrix_13 KL term3 (Mean difference): 26.83619371545546
# matrix_13 KL result: 136.81978679178957
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.426886804662555
# matrix_23 KL term3 (Mean difference): 5.161738537392713
# matrix_23 KL result: 127.79431267102763
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.872453147598408
# matrix_12 KL term3 (Mean difference): 24.694707319255
# matrix_12 KL result: 137.7835802334267
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 10.17140939153085
# matrix_13 KL term3 (Mean difference): 26.560711027558526
# matrix_13 KL result: 138.86606020954468
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.541774541864429
# matrix_23 KL term3 (Mean difference): 27.831182514591703
# matrix_23 KL result: 139.18647852822806
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 10.569103165240175
# matrix_12 KL term3 (Mean difference): 2.2642323732747207
# matrix_12 KL result: 126.91666776925743
# matrix_13 KL term1 (Trace): 152.98484470825434
# matrix_13 KL term2 (Log determinant difference): 13.187991939856841
# matrix_13 KL term3 (Mean difference): 4.895573832663431
# matrix_13 KL result: 81.03420524038731
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 12.120138886272374
# matrix_23 KL term3 (Mean difference): 40.273270198870996
# matrix_23 KL result: 146.6967045425717
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.78439331761766
# matrix_12 KL term3 (Mean difference): 149.48105231317675
# matrix_12 KL result: 199.63272281539722
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 11.389582895638222
# matrix_13 KL term3 (Mean difference): 235.7518753325725
# matrix_13 KL result: 244.07072911410535
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 11.910808801221707
# matrix_23 KL term3 (Mean difference): 79.45898192027823
# matrix_23 KL result: 166.18489536074998
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.525907870811814
# matrix_12 KL term3 (Mean difference): 227.81204627032523
# matrix_12 KL result: 238.16897707056853
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.248439220584347
# matrix_13 KL term3 (Mean difference): 233.98470972627143
# matrix_13 KL result: 241.6165744734279
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.940581555193157
# matrix_23 KL term3 (Mean difference): 86.02645511353168
# matrix_23 KL result: 168.48351833436243
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.24033516667647
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.12016758333823
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.282362110508954
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.14118105525446
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.300935200579195
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.1504676002896
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 12.146144589873643
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 251.57307229493682
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.986533875842571
# matrix_13 KL term3 (Mean difference): 131.09281389938013
# matrix_13 KL result: 190.53967388761134
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 6.0782224093092445
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 248.53911120465463
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.649193745358874
# matrix_12 KL term3 (Mean difference): 94.02821339498261
# matrix_12 KL result: 171.33870357017076
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.611544725388448
# matrix_13 KL term3 (Mean difference): 175.404034967707
# matrix_13 KL result: 213.00778984654772
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 11.195342678112656
# matrix_23 KL term3 (Mean difference): 23.94418577066639
# matrix_23 KL result: 138.0697642243895
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 4.121493921746104
# matrix_12 KL term3 (Mean difference): 151.81602866983926
# matrix_12 KL result: 198.46876129579266
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 4.434143323122122
# matrix_13 KL term3 (Mean difference): 126.50255152301112
# matrix_13 KL result: 185.96834742306663
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.96676851838755
# matrix_23 KL term3 (Mean difference): 5.619215720947708
# matrix_23 KL result: 128.29299211966762
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 5.930238078653428
# matrix_12 KL term3 (Mean difference): 97.59520711220581
# matrix_12 KL result: 172.2627225954296
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 6.123836844781959
# matrix_13 KL term3 (Mean difference): 103.96705442222856
# matrix_13 KL result: 175.54544563350527
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.413669759513379
# matrix_23 KL term3 (Mean difference): 16.11145056696928
# matrix_23 KL result: 133.26256016324132
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.143992598370428
# matrix_12 KL term3 (Mean difference): 113.27468420894316
# matrix_12 KL result: 181.70933840365677
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.284228249607484
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.14211412480375
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.400969661015132
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.20048483050758
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 15.95303904061604
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 253.476519520308
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.415672673463519
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.20783633673176
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 2.6762282038840723
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 246.83811410194204
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.707615350001614
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.3538076750008
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.470900698121891
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.23545034906095
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.995585164568109
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.99779258228406
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 10.188009942284033
# matrix_12 KL term3 (Mean difference): 180.36571578694887
# matrix_12 KL result: 215.77686286461648
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.93863777399532
# matrix_13 KL term3 (Mean difference): 91.75073948453613
# matrix_13 KL result: 170.8446886292657
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.030779246687123
# matrix_23 KL term3 (Mean difference): 11.310897958685832
# matrix_23 KL result: 130.17083860268647
# matrix_12 KL term1 (Trace): 223.990924351432
# matrix_12 KL term2 (Log determinant difference): 10.172998307287523
# matrix_12 KL term3 (Mean difference): 167.27729073337795
# matrix_12 KL result: 196.22060669604872
# matrix_13 KL term1 (Trace): 148.76795127009427
# matrix_13 KL term2 (Log determinant difference): 9.685527959045979
# matrix_13 KL term3 (Mean difference): 176.27474109913356
# matrix_13 KL result: 162.8641101641369
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.826866911668263
# matrix_23 KL term3 (Mean difference): 163.02319462742668
# matrix_23 KL result: 206.42503076954748
# matrix_12 KL term1 (Trace): 71.107123067249
# matrix_12 KL term2 (Log determinant difference): 10.754247200664345
# matrix_12 KL term3 (Mean difference): 11.65371183673994
# matrix_12 KL result: 42.257541052326644
# matrix_13 KL term1 (Trace): 27.707673943259707
# matrix_13 KL term2 (Log determinant difference): 10.644009428209042
# matrix_13 KL term3 (Mean difference): 3.51701698196989
# matrix_13 KL result: 16.43435017671932
# matrix_23 KL term1 (Trace): 56.8027435041252
# matrix_23 KL term2 (Log determinant difference): 10.545716641608564
# matrix_23 KL term3 (Mean difference): 9.370497452346248
# matrix_23 KL result: 33.859478799040005
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.97211183382751
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.48605591691376
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 13.93551815611349
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 252.46775907805676
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 13.739860758973522
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 252.36993037948673
# matrix_12 KL term1 (Trace): 40.06419349854657
# matrix_12 KL term2 (Log determinant difference): 10.853536892660506
# matrix_12 KL term3 (Mean difference): 5.212798272704073
# matrix_12 KL result: 23.565264331955575
# matrix_13 KL term1 (Trace): 53.85127134932914
# matrix_13 KL term2 (Log determinant difference): 11.01433853178835
# matrix_13 KL term3 (Mean difference): 7.036946076582327
# matrix_13 KL result: 31.45127797884991
# matrix_23 KL term1 (Trace): 176.31806761801028
# matrix_23 KL term2 (Log determinant difference): 9.454084975680889
# matrix_23 KL term3 (Mean difference): 14.879800768298669
# matrix_23 KL result: 95.82597668099493
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 5.698122891879816
# matrix_12 KL term3 (Mean difference): 14.561131851864968
# matrix_12 KL result: 130.6296273718724
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 5.307885647685092
# matrix_13 KL term3 (Mean difference): 16.186122889394507
# matrix_13 KL result: 131.2470042685398
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.828275149449587
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.9141375747248
# matrix_12 KL term1 (Trace): 161.59679231053076
# matrix_12 KL term2 (Log determinant difference): 8.96160707747984
# matrix_12 KL term3 (Mean difference): 27.26512419441128
# matrix_12 KL result: 94.41176179121094
# matrix_13 KL term1 (Trace): 204.5424474276519
# matrix_13 KL term2 (Log determinant difference): 9.63440406385335
# matrix_13 KL term3 (Mean difference): 52.163358201746256
# matrix_13 KL result: 128.67010484662575
# matrix_23 KL term1 (Trace): 243.80627891238876
# matrix_23 KL term2 (Log determinant difference): 9.956750519847681
# matrix_23 KL term3 (Mean difference): 50.16449047634442
# matrix_23 KL result: 147.46375995429042
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 11.489550881063218
# matrix_12 KL term3 (Mean difference): 184.9720737836166
# matrix_12 KL result: 218.7308123323399
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 10.102231043269585
# matrix_13 KL term3 (Mean difference): 117.95657614862327
# matrix_13 KL result: 184.5294035959464
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 7.844359638490053
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.42217981924503
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.802436486001948
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.90121824300098
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.356383873219084
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.17819193660955
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.82617543164756
# matrix_23 KL term3 (Mean difference): 155.49276753760174
# matrix_23 KL result: 203.15947148462465
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.862533860624822
# matrix_12 KL term3 (Mean difference): 20.83613315495784
# matrix_12 KL result: 135.84933350779133
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 11.794089829858173
# matrix_13 KL term3 (Mean difference): 11.08331602119808
# matrix_13 KL result: 131.93870292552813
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 11.185080024785286
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 251.09254001239265
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.429944542302422
# matrix_12 KL term3 (Mean difference): 35.7946610428932
# matrix_12 KL result: 142.61230279259783
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.2313883506886
# matrix_13 KL term3 (Mean difference): 41.67055463121855
# matrix_13 KL result: 145.95097149095358
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 10.105358682578629
# matrix_23 KL term3 (Mean difference): 21.469810920433986
# matrix_23 KL result: 136.2875848015063
# matrix_12 KL term1 (Trace): 117.9616054935399
# matrix_12 KL term2 (Log determinant difference): 10.253110078464966
# matrix_12 KL term3 (Mean difference): 24.614427087156646
# matrix_12 KL result: 71.91457132958077
# matrix_13 KL term1 (Trace): 235.8217357727752
# matrix_13 KL term2 (Log determinant difference): 10.86654964848609
# matrix_13 KL term3 (Mean difference): 8.280031324474326
# matrix_13 KL result: 122.98415837286781
# matrix_23 KL term1 (Trace): 218.881950276746
# matrix_23 KL term2 (Log determinant difference): 11.050175912981237
# matrix_23 KL term3 (Mean difference): 156.22303595648305
# matrix_23 KL result: 188.57758107310514
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 12.114581856221138
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 251.55729092811055
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.604862000307904
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.30243100015394
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.205545087468728
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.60277254373437
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.443529324897682
# matrix_12 KL term3 (Mean difference): 18.366973084583826
# matrix_12 KL result: 134.40525120474075
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.39081328661142
# matrix_13 KL term3 (Mean difference): 29.753389095181202
# matrix_13 KL result: 140.07210119089632
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.197426921181131
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.09871346059057
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.711061335730063
# matrix_12 KL term3 (Mean difference): 46.01978466800286
# matrix_12 KL result: 147.86542300186645
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 10.245639643907921
# matrix_13 KL term3 (Mean difference): 50.93411323988539
# matrix_13 KL result: 151.08987644189665
# matrix_23 KL term1 (Trace): 218.1076041059114
# matrix_23 KL term2 (Log determinant difference): 10.789784000290155
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 234.94869405310078
# matrix_12 KL term1 (Trace): 29.386632868625668
# matrix_12 KL term2 (Log determinant difference): 11.666926124930129
# matrix_12 KL term3 (Mean difference): 40.13242962269094
# matrix_12 KL result: 36.092994308123366
# matrix_13 KL term1 (Trace): 20.87188633727292
# matrix_13 KL term2 (Log determinant difference): 11.307970444109928
# matrix_13 KL term3 (Mean difference): 29.03703000718235
# matrix_13 KL result: 26.108443394282595
# matrix_23 KL term1 (Trace): 63.149098216594766
# matrix_23 KL term2 (Log determinant difference): 10.73727460011697
# matrix_23 KL term3 (Mean difference): 22.680726847058835
# matrix_23 KL result: 43.78354983188529
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.649406080883995
# matrix_12 KL term3 (Mean difference): 67.43168339526453
# matrix_12 KL result: 158.54054473807426
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.491397194049412
# matrix_13 KL term3 (Mean difference): 76.18781754692019
# matrix_13 KL result: 162.8396073704848
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.089462545903025
# matrix_23 KL term3 (Mean difference): 1.3835520237766534
# matrix_23 KL result: 125.73650728483983
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.215469612010331
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.10773480600517
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 10.333953296474617
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.6669766482373
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 10.352394248558324
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.67619712427916
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.929280421816083
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.96464021090804
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.774926093541206
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 249.8874630467706
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.145864034594437
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.0729320172972
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.084517085371278
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.04225854268563
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.66686829398169
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 249.83343414699084
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.846108236824634
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.92305411841232
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.489216022646136
# matrix_12 KL term3 (Mean difference): 69.9867077026739
# matrix_12 KL result: 160.23796186266003
# matrix_13 KL term1 (Trace): 130.99279571191886
# matrix_13 KL term2 (Log determinant difference): 13.498311146780054
# matrix_13 KL term3 (Mean difference): 37.45287072343527
# matrix_13 KL result: 86.47198879106709
# matrix_23 KL term1 (Trace): 158.24749306540565
# matrix_23 KL term2 (Log determinant difference): 13.294881830160122
# matrix_23 KL term3 (Mean difference): 15.574681769165496
# matrix_23 KL result: 89.05852833236564
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.32745350902789
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.16372675451396
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.790152037203146
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 249.89507601860157
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.695361555621016
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.8476807778105
# matrix_12 KL term1 (Trace): 35.5654257817485
# matrix_12 KL term2 (Log determinant difference): 9.662449834792953
# matrix_12 KL term3 (Mean difference): 13.988461935683889
# matrix_12 KL result: 25.10816877611267
# matrix_13 KL term1 (Trace): 25.788898349077556
# matrix_13 KL term2 (Log determinant difference): 9.35897546751689
# matrix_13 KL term3 (Mean difference): 7.700585162813275
# matrix_13 KL result: 16.924229489703862
# matrix_23 KL term1 (Trace): 39.44661498705433
# matrix_23 KL term2 (Log determinant difference): 10.05975566721193
# matrix_23 KL term3 (Mean difference): 8.370466838337492
# matrix_23 KL result: 24.438418746301878
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.583438570481238
# matrix_12 KL term3 (Mean difference): 13.21313708919581
# matrix_12 KL result: 131.39828782983852
# matrix_13 KL term1 (Trace): 166.94167815955225
# matrix_13 KL term2 (Log determinant difference): 7.505863225748694
# matrix_13 KL term3 (Mean difference): 8.63120376701162
# matrix_13 KL result: 87.03937257615628
# matrix_23 KL term1 (Trace): 87.04912911390794
# matrix_23 KL term2 (Log determinant difference): 8.72758301621834
# matrix_23 KL term3 (Mean difference): 2.6527595437261846
# matrix_23 KL result: 44.71473583692623
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.88057947040547
# matrix_12 KL term3 (Mean difference): 115.66631650640645
# matrix_12 KL result: 182.27344798840596
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 7.416802817635567
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 249.2084014088178
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.813946777328162
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.90697338866408
# matrix_12 KL term1 (Trace): 109.75909781662088
# matrix_12 KL term2 (Log determinant difference): 10.963843784546567
# matrix_12 KL term3 (Mean difference): 235.4930446977899
# matrix_12 KL result: 173.6079931494787
# matrix_13 KL term1 (Trace): 154.28971053341309
# matrix_13 KL term2 (Log determinant difference): 10.33772134385204
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 202.81371593863258
# matrix_23 KL term1 (Trace): 177.97377650275183
# matrix_23 KL term2 (Log determinant difference): 9.153033578559986
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 214.0634050406559
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.757930299219897
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.37896514960994
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.343275518786871
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.17163775939343
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 10.805592362836173
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.9027961814181
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.976232545529383
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.9881162727647
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.281743042234474
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 249.64087152111725
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.546528389159093
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.77326419457955
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 10.26658788001534
# matrix_12 KL term3 (Mean difference): 78.84561965762366
# matrix_12 KL result: 165.0561037688195
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 11.107869167370993
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 251.0539345836855
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 10.055167091820945
# matrix_23 KL term3 (Mean difference): 69.12114027580856
# matrix_23 KL result: 160.08815368381474
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 10.411659171610776
# matrix_12 KL term3 (Mean difference): 137.2236057967567
# matrix_12 KL result: 194.31763248418372
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.629477100899441
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.31473855044973
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.439092306856915
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.71954615342847
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 12.284724667563399
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 251.6423623337817
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 7.331236083801116
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 249.16561804190056
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 4.268859078184557
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 247.63442953909228
# matrix_12 KL term1 (Trace): 135.7694551198872
# matrix_12 KL term2 (Log determinant difference): 10.333275448134067
# matrix_12 KL term3 (Mean difference): 6.668036136089944
# matrix_12 KL result: 71.8853833520556
# matrix_13 KL term1 (Trace): 67.18461633052894
# matrix_13 KL term2 (Log determinant difference): 10.3311756089323
# matrix_13 KL term3 (Mean difference): 9.061233054521077
# matrix_13 KL result: 38.78851249699116
# matrix_23 KL term1 (Trace): 191.4824807584924
# matrix_23 KL term2 (Log determinant difference): 10.845743578743209
# matrix_23 KL term3 (Mean difference): 40.24466595657463
# matrix_23 KL result: 116.78644514690511
# matrix_12 KL term1 (Trace): 56.368338064104236
# matrix_12 KL term2 (Log determinant difference): 10.46685502672548
# matrix_12 KL term3 (Mean difference): 7.795788016400043
# matrix_12 KL result: 32.81549055361488
# matrix_13 KL term1 (Trace): 63.88030159627825
# matrix_13 KL term2 (Log determinant difference): 11.647856695224991
# matrix_13 KL term3 (Mean difference): 4.6384749209082745
# matrix_13 KL result: 35.58331660620576
# matrix_23 KL term1 (Trace): 49.58832601932516
# matrix_23 KL term2 (Log determinant difference): 11.351639908067103
# matrix_23 KL term3 (Mean difference): 5.723822592525405
# matrix_23 KL result: 28.831894259958837
# matrix_12 KL term1 (Trace): 52.325329919101456
# matrix_12 KL term2 (Log determinant difference): 10.069396325437143
# matrix_12 KL term3 (Mean difference): 15.476633890021503
# matrix_12 KL result: 34.43568006728005
# matrix_13 KL term1 (Trace): 105.5132642054181
# matrix_13 KL term2 (Log determinant difference): 10.123292550169001
# matrix_13 KL term3 (Mean difference): 29.006105060950926
# matrix_13 KL result: 67.821330908269
# matrix_23 KL term1 (Trace): 71.44395228456648
# matrix_23 KL term2 (Log determinant difference): 10.139445654898697
# matrix_23 KL term3 (Mean difference): 6.516725329261719
# matrix_23 KL result: 39.550061634363445
# matrix_12 KL term1 (Trace): 17.413467208992245
# matrix_12 KL term2 (Log determinant difference): 9.949982647276919
# matrix_12 KL term3 (Mean difference): 38.893429272787664
# matrix_12 KL result: 28.628439564528414
# matrix_13 KL term1 (Trace): 11.62734974154521
# matrix_13 KL term2 (Log determinant difference): 9.611273353788949
# matrix_13 KL term3 (Mean difference): 19.182825717571518
# matrix_13 KL result: 15.71072440645284
# matrix_23 KL term1 (Trace): 14.631308443279494
# matrix_23 KL term2 (Log determinant difference): 9.790083607807905
# matrix_23 KL term3 (Mean difference): 30.36107592014306
# matrix_23 KL result: 22.89123398561523
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.378700067210692
# matrix_12 KL term3 (Mean difference): 178.31928694104653
# matrix_12 KL result: 214.3489935041286
# matrix_13 KL term1 (Trace): 226.12836846076888
# matrix_13 KL term2 (Log determinant difference): 8.620881344262468
# matrix_13 KL term3 (Mean difference): 113.73959198484658
# matrix_13 KL result: 169.74442089493897
# matrix_23 KL term1 (Trace): 231.48075664649213
# matrix_23 KL term2 (Log determinant difference): 8.530058913961895
# matrix_23 KL term3 (Mean difference): 27.007360137362422
# matrix_23 KL result: 129.00908784890822
# matrix_12 KL term1 (Trace): 88.78071644838141
# matrix_12 KL term2 (Log determinant difference): 9.732624858574331
# matrix_12 KL term3 (Mean difference): 21.029069672869195
# matrix_12 KL result: 55.27120548991247
# matrix_13 KL term1 (Trace): 158.39228263579184
# matrix_13 KL term2 (Log determinant difference): 9.173618318571583
# matrix_13 KL term3 (Mean difference): 39.49439686279361
# matrix_13 KL result: 99.03014890857852
# matrix_23 KL term1 (Trace): 112.71485153342192
# matrix_23 KL term2 (Log determinant difference): 8.686933783410405
# matrix_23 KL term3 (Mean difference): 1.886672128919178
# matrix_23 KL result: 57.14422872287575
# matrix_12 KL term1 (Trace): 36.207267171470775
# matrix_12 KL term2 (Log determinant difference): 10.25121424713185
# matrix_12 KL term3 (Mean difference): 66.39678495745031
# matrix_12 KL result: 51.92763318802646
# matrix_13 KL term1 (Trace): 25.042843222178764
# matrix_13 KL term2 (Log determinant difference): 9.551656270253579
# matrix_13 KL term3 (Mean difference): 34.89555195250481
# matrix_13 KL result: 30.245025722468576
# matrix_23 KL term1 (Trace): 36.35915082000842
# matrix_23 KL term2 (Log determinant difference): 9.610829841772636
# matrix_23 KL term3 (Mean difference): 55.80374895751816
# matrix_23 KL result: 46.38686480964961
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 6.82629114704941
# matrix_12 KL term3 (Mean difference): 32.27830557542353
# matrix_12 KL result: 140.05229836123647
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 6.5208518728585805
# matrix_13 KL term3 (Mean difference): 45.95209946544912
# matrix_13 KL result: 146.73647566915386
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.99458559313919
# matrix_23 KL term3 (Mean difference): 226.10524675880663
# matrix_23 KL result: 238.0499161759729
# matrix_12 KL term1 (Trace): 31.017606534035423
# matrix_12 KL term2 (Log determinant difference): 10.221586435869055
# matrix_12 KL term3 (Mean difference): 3.010919179059917
# matrix_12 KL result: 17.6250560744822
# matrix_13 KL term1 (Trace): 47.644196090563575
# matrix_13 KL term2 (Log determinant difference): 9.417281553405385
# matrix_13 KL term3 (Mean difference): 5.071547000116048
# matrix_13 KL result: 26.566512322042502
# matrix_23 KL term1 (Trace): 63.65249642899816
# matrix_23 KL term2 (Log determinant difference): 8.794881166933568
# matrix_23 KL term3 (Mean difference): 0.9117782248793838
# matrix_23 KL result: 32.179577910405555
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 11.374000953651725
# matrix_12 KL term3 (Mean difference): 4.928530679909297
# matrix_12 KL result: 128.6512658167805
# matrix_13 KL term1 (Trace): 161.75276915430902
# matrix_13 KL term2 (Log determinant difference): 12.8987930572997
# matrix_13 KL term3 (Mean difference): 6.016037728621891
# matrix_13 KL result: 85.83379997011531
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 10.80328636959266
# matrix_23 KL term3 (Mean difference): 248.47655012623994
# matrix_23 KL result: 250.1399182479163
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.847561007614567
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.42378050380728
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.026166491846872
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 249.51308324592344
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.395042566853768
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.19752128342688
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.395486901982435
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.69774345099123
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.338842822173637
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.16942141108683
# matrix_23 KL term1 (Trace): 244.6572376124254
# matrix_23 KL term2 (Log determinant difference): 10.1998983568524
# matrix_23 KL term3 (Mean difference): 160.5378245115699
# matrix_23 KL result: 203.19748024042386
# matrix_12 KL term1 (Trace): 131.7867725859573
# matrix_12 KL term2 (Log determinant difference): 9.466243054745808
# matrix_12 KL term3 (Mean difference): 95.10178649002661
# matrix_12 KL result: 113.67740106536485
# matrix_13 KL term1 (Trace): 129.38189949030468
# matrix_13 KL term2 (Log determinant difference): 9.607258966413987
# matrix_13 KL term3 (Mean difference): 183.01602161463106
# matrix_13 KL result: 156.50259003567487
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.435444648042104
# matrix_23 KL term3 (Mean difference): 7.4885515167585694
# matrix_23 KL result: 128.96199808240033
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.22688375716416
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.61344187858208
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 10.191949836157736
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.59597491807887
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 11.184013729474067
# matrix_23 KL term3 (Mean difference): 109.0619061945358
# matrix_23 KL result: 180.62295996200493
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.818304611119864
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.40915230555993
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 11.639999919364538
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 251.31999995968226
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 11.739567967074507
# matrix_23 KL term3 (Mean difference): 134.42534888793452
# matrix_23 KL result: 193.5824584275045
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.046525607203371
# matrix_12 KL term3 (Mean difference): 148.28701198916016
# matrix_12 KL result: 199.16676879818175
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 12.215146109320706
# matrix_13 KL term3 (Mean difference): 77.76019334386957
# matrix_13 KL result: 165.48766972659513
# matrix_23 KL term1 (Trace): 182.46753370333235
# matrix_23 KL term2 (Log determinant difference): 12.479630464815102
# matrix_23 KL term3 (Mean difference): 2.8240160360275026
# matrix_23 KL result: 94.38559010208748
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 10.353483114534036
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.676741557267
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.012898852330098
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 249.50644942616506
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 6.920782643216851
# matrix_23 KL term3 (Mean difference): 63.46052667542227
# matrix_23 KL result: 155.69065465931956
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 14.16263938315954
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 252.58131969157978
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.9030857528818
# matrix_13 KL term3 (Mean difference): 63.10383454971093
# matrix_13 KL result: 156.50346015129637
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 3.7347446373418576
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 247.36737231867093
# matrix_12 KL term1 (Trace): 147.85111875459805
# matrix_12 KL term2 (Log determinant difference): 9.098764441944532
# matrix_12 KL term3 (Mean difference): 32.863946798559176
# matrix_12 KL result: 90.40691499755087
# matrix_13 KL term1 (Trace): 181.69058616770064
# matrix_13 KL term2 (Log determinant difference): 11.838374182283617
# matrix_13 KL term3 (Mean difference): 22.381273856828507
# matrix_13 KL result: 103.45511710340638
# matrix_23 KL term1 (Trace): 48.874210868692145
# matrix_23 KL term2 (Log determinant difference): 13.876558505994145
# matrix_23 KL term3 (Mean difference): 12.210042218105093
# matrix_23 KL result: 32.980405796395694
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 10.921163159316615
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.9605815796583
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 12.645532565892648
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 251.8227662829463
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 11.021873712893868
# matrix_23 KL term3 (Mean difference): 30.12882620281165
# matrix_23 KL result: 141.07534995785275
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.600456167571146
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.30022808378558
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.749760521040372
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 249.87488026052017
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.40414720088227
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.70207360044114
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 10.792623287923805
# matrix_12 KL term3 (Mean difference): 240.15902322536323
# matrix_12 KL result: 245.9758232566435
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 10.995521842534824
# matrix_13 KL term3 (Mean difference): 250
# ...
# matrix_13 KL result: 134.17580865846546
# matrix_23 KL term1 (Trace): 187.81368927791513
# matrix_23 KL term2 (Log determinant difference): 15.481324338355087
# matrix_23 KL term3 (Mean difference): 3.6437225650006204
# matrix_23 KL result: 98.96936809063541
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.767724166313938
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.38386208315697
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.601193715938894
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 249.80059685796945
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 10.051923716061577
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.5259618580308
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 10.612110880982101
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.80605544049104
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 10.79490020727313
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.89745010363657
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 10.846129832639118
# matrix_23 KL term3 (Mean difference): 167.4246645232647
# matrix_23 KL result: 209.63539717795192
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.253838377561163
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.1269191887806
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.664359171964799
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.3321795859824
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.634839750662698
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.31741987533135
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.101016938367168
# matrix_12 KL term3 (Mean difference): 122.3210754009394
# matrix_12 KL result: 185.7110461696533
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.637925980013343
# matrix_13 KL term3 (Mean difference): 119.0192941840941
# matrix_13 KL result: 184.82861008205373
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 10.806124523814635
# matrix_23 KL term3 (Mean difference): 211.29952937696754
# matrix_23 KL result: 231.55282695039108
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 4.842027009419761
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 247.9210135047099
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 5.127176961651532
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 248.06358848082579
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.52419454936191
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.26209727468097
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.062425079155442
# matrix_12 KL term3 (Mean difference): 109.8848476395257
# matrix_12 KL result: 179.97363635934056
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 7.085501061733181
# matrix_13 KL term3 (Mean difference): 131.300761285351
# matrix_13 KL result: 189.6931311735421
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 7.279649590412268
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.13982479520612
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.550329329719652
# matrix_12 KL term3 (Mean difference): 90.65656436052699
# matrix_12 KL result: 170.10344684512333
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 10.457119573328704
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.72855978666436
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 11.163920191459017
# matrix_23 KL term3 (Mean difference): 191.45590444087352
# matrix_23 KL result: 221.80991231616628
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 6.933137775760931
# matrix_12 KL term3 (Mean difference): 184.5869811867545
# matrix_12 KL result: 216.2600594812577
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.56254486853008
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.28127243426505
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 11.932383223020748
# matrix_23 KL term3 (Mean difference): 59.11590400632457
# matrix_23 KL result: 156.02414361467265
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 5.454737960020948
# matrix_12 KL term3 (Mean difference): 11.049942295202754
# matrix_12 KL result: 128.75234012761183
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 4.8524306523274845
# matrix_13 KL term3 (Mean difference): 11.008268744703276
# matrix_13 KL result: 128.43034969851539
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.657430913026392
# matrix_23 KL term3 (Mean difference): 142.44533589879478
# matrix_23 KL result: 196.0513834059106
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 4.535767394523964
# matrix_12 KL term3 (Mean difference): 52.58292376207851
# matrix_12 KL result: 149.05934557830125
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 5.0526988166725975
# matrix_13 KL term3 (Mean difference): 44.31951730284663
# matrix_13 KL result: 145.18610805975962
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.776711963007058
# matrix_23 KL term3 (Mean difference): 7.522852532833526
# matrix_23 KL result: 129.1497822479203
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.837968688271186
# matrix_12 KL term3 (Mean difference): 4.220161434691294
# matrix_12 KL result: 127.52906506148125
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 11.478552532850054
# matrix_13 KL term3 (Mean difference): 9.259009289737692
# matrix_13 KL result: 130.8687809112939
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 10.97940639804341
# matrix_23 KL term3 (Mean difference): 27.798234246735735
# matrix_23 KL result: 139.88882032238956
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 6.636778830864243
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 248.8183894154321
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 6.632251769423444
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 248.8161258847117
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.240864374141612
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.1204321870708
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.842886851308283
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.92144342565413
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.136755461483586
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 249.5683777307418
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.5152877830834
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 249.7576438915417
# matrix_12 KL term1 (Trace): 13.325920249610457
# matrix_12 KL term2 (Log determinant difference): 9.847411358340155
# matrix_12 KL term3 (Mean difference): 10.513137367275396
# matrix_12 KL result: 12.343234487613003
# matrix_13 KL term1 (Trace): 12.309655033957169
# matrix_13 KL term2 (Log determinant difference): 9.61039373429168
# matrix_13 KL term3 (Mean difference): 5.370469113658194
# matrix_13 KL result: 9.145258940953521
# matrix_23 KL term1 (Trace): 19.45890273453459
# matrix_23 KL term2 (Log determinant difference): 10.615231405149267
# matrix_23 KL term3 (Mean difference): 28.016504575746715
# matrix_23 KL result: 24.545319357715286
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.425096942885949
# matrix_12 KL term3 (Mean difference): 13.595987167968527
# matrix_12 KL result: 131.01054205542724
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 6.846487501182436
# matrix_13 KL term3 (Mean difference): 8.341987182293764
# matrix_13 KL result: 128.0942373417381
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 8.684399184267667
# matrix_23 KL term3 (Mean difference): 124.68260732343384
# matrix_23 KL result: 187.18350325385074
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.318756814755298
# matrix_12 KL term3 (Mean difference): 75.9986218094206
# matrix_12 KL result: 163.15868931208797
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 7.872003521727498
# matrix_13 KL term3 (Mean difference): 72.44517549722596
# matrix_13 KL result: 160.6585895094767
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 7.789193609896669
# matrix_23 KL term3 (Mean difference): 29.072019747544285
# matrix_23 KL result: 138.93060667872047
# matrix_12 KL term1 (Trace): 84.85484751018518
# matrix_12 KL term2 (Log determinant difference): 8.113261421342036
# matrix_12 KL term3 (Mean difference): 68.02575176131302
# matrix_12 KL result: 75.99693034642011
# matrix_13 KL term1 (Trace): 65.11140308339778
# matrix_13 KL term2 (Log determinant difference): 8.563493344636651
# matrix_13 KL term3 (Mean difference): 52.36517166709071
# matrix_13 KL result: 58.520034047562575
# matrix_23 KL term1 (Trace): 97.50677886540788
# matrix_23 KL term2 (Log determinant difference): 9.82896566553724
# matrix_23 KL term3 (Mean difference): 50.11580776758602
# matrix_23 KL result: 74.22577614926557
# matrix_12 KL term1 (Trace): 135.54981045575803
# matrix_12 KL term2 (Log determinant difference): 9.837545733012567
# matrix_12 KL term3 (Mean difference): 109.89213335684458
# matrix_12 KL result: 123.1397447728076
# matrix_13 KL term1 (Trace): 196.27755460793864
# matrix_13 KL term2 (Log determinant difference): 10.76249003906695
# matrix_13 KL term3 (Mean difference): 160.721208945521
# matrix_13 KL result: 179.3806267962633
# matrix_23 KL term1 (Trace): 140.03645203404955
# matrix_23 KL term2 (Log determinant difference): 11.106901389870806
# matrix_23 KL term3 (Mean difference): 3.0689018936182855
# matrix_23 KL result: 72.60612765876932
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.64541821757961
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.3227091087898
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.630007408576587
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.3150037042883
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.210014953268784
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.1050074766344
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 7.371445860725602
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.1857229303628
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 8.545560955208797
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 249.77278047760439
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 10.3970365952829
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.69851829764144
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 8.024478692440356
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 249.51223934622018
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 10.125201139248809
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.5626005696244
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 11.319222883313778
# matrix_23 KL term3 (Mean difference): 168.86423973196747
# matrix_23 KL result: 210.59173130764063
# matrix_12 KL term1 (Trace): 6.2710133677863915
# matrix_12 KL term2 (Log determinant difference): 10.878020976220098
# matrix_12 KL term3 (Mean difference): 2.5471251015519036
# matrix_12 KL result: 5.348079722779195
# matrix_13 KL term1 (Trace): 6.025295437953579
# matrix_13 KL term2 (Log determinant difference): 11.250974622363
# matrix_13 KL term3 (Mean difference): 2.4602203321879355
# matrix_13 KL result: 5.368245196252257
# matrix_23 KL term1 (Trace): 7.172741644997811
# matrix_23 KL term2 (Log determinant difference): 11.454270405590822
# matrix_23 KL term3 (Mean difference): 5.851185467405805
# matrix_23 KL result: 7.739098758997219
# matrix_12 KL term1 (Trace): 172.65387408715463
# matrix_12 KL term2 (Log determinant difference): 8.390597318845796
# matrix_12 KL term3 (Mean difference): 7.728766689662576
# matrix_12 KL result: 89.8866190478315
# matrix_13 KL term1 (Trace): 233.199909521365
# matrix_13 KL term2 (Log determinant difference): 9.773550527629993
# matrix_13 KL term3 (Mean difference): 13.587760197963057
# matrix_13 KL result: 123.78061012347902
# matrix_23 KL term1 (Trace): 106.26093700534857
# matrix_23 KL term2 (Log determinant difference): 10.821045357921097
# matrix_23 KL term3 (Mean difference): 8.254142591911709
# matrix_23 KL result: 58.16806247759068
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.454513441904083
# matrix_12 KL term3 (Mean difference): 250
# matrix_12 KL result: 250.22725672095203
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.481414453631587
# matrix_13 KL term3 (Mean difference): 250
# matrix_13 KL result: 250.2407072268158
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.281100330946497
# matrix_23 KL term3 (Mean difference): 250
# matrix_23 KL result: 250.14055016547326
# matrix_12 KL term1 (Trace): 80.67910437490521
# matrix_12 KL term2 (Log determinant difference): 9.661804026517904
# matrix_12 KL term3 (Mean difference): 196.81188067570713
# matrix_12 KL result: 139.07639453856513
# matrix_13 KL term1 (Trace): 59.18209939699287
# matrix_13 KL term2 (Log determinant difference): 8.680262401109118
# matrix_13 KL term3 (Mean difference): 138.22915421738722
# matrix_13 KL result: 98.54575800774461
# matrix_23 KL term1 (Trace): 57.16212425433997
# matrix_23 KL term2 (Log determinant difference): 8.675120021976781
# matrix_23 KL term3 (Mean difference): 149.80578797986306
# matrix_23 KL result: 103.32151612808991
# matrix_12 KL term1 (Trace): 134.39499565838554
# matrix_12 KL term2 (Log determinant difference): 8.095849037116949
# matrix_12 KL term3 (Mean difference): 66.36164451747749
# matrix_12 KL result: 99.92624460648999
# matrix_13 KL term1 (Trace): 152.57665841244628
# matrix_13 KL term2 (Log determinant difference): 10.338059573630439
# matrix_13 KL term3 (Mean difference): 70.66314565758525
# matrix_13 KL result: 112.28893182183097
# matrix_23 KL term1 (Trace): 51.569167712919445
# matrix_23 KL term2 (Log determinant difference): 11.550582321514689
# matrix_23 KL term3 (Mean difference): 5.677866804536436
# matrix_23 KL result: 29.898808419485285
# matrix_12 KL term1 (Trace): 250
# matrix_12 KL term2 (Log determinant difference): 9.168211054535993
# matrix_12 KL term3 (Mean difference): 49.08357662327889
# matrix_12 KL result: 149.62589383890744
# matrix_13 KL term1 (Trace): 250
# matrix_13 KL term2 (Log determinant difference): 9.584209371665413
# matrix_13 KL term3 (Mean difference): 114.6658207146807
# matrix_13 KL result: 182.62501504317305
# matrix_23 KL term1 (Trace): 250
# matrix_23 KL term2 (Log determinant difference): 9.651315958569683
# matrix_23 KL term3 (Mean difference): 206.2402206685967
# matrix_23 KL result: 228.4457683135832
# KL divergence results saved to kl_divergence_results_regularized.csv
